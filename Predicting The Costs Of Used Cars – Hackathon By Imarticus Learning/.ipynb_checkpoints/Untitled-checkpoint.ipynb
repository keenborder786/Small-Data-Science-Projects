# %%
from tensorflow import keras
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor

# %%
df=pd.read_excel("train.xlsx")
df_test=pd.read_excel("test.xlsx")

# %%
df
# Out:
#                                                   Name    Location  Year  \
# 0                               Maruti Wagon R LXI CNG      Mumbai  2010
# 1                     Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                         Honda Jazz V     Chennai  2011
# 3                                    Maruti Ertiga VDI     Chennai  2012
# 4                      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# 5                      Hyundai EON LPG Era Plus Option   Hyderabad  2012
# 6                               Nissan Micra Diesel XV      Jaipur  2013
# 7                    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016
# 8                  Volkswagen Vento Diesel Comfortline        Pune  2013
# 9                       Tata Indica Vista Quadrajet LS     Chennai  2012
# 10                                    Maruti Ciaz Zeta       Kochi  2018
# 11                         Honda City 1.5 V AT Sunroof     Kolkata  2012
# ...

# %%
df.set_index((df.columns[0]))
df.drop("New_Price",1,inplace=True)

# %%
df.head()
df.fillna(value=0,inplace=True)
df.isnull().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
LabelEncoder=LabelEncoder()
df["Location"]=LabelEncoder.fit_transform(df["Location"])
df["Year"]=LabelEncoder.fit_transform(df["Year"])
df["Fuel_Type"]=LabelEncoder.fit_transform(df["Fuel_Type"])
df["Owner_Type"]=LabelEncoder.fit_transform(df["Owner_Type"])
df["Transmission"]=LabelEncoder.fit_transform(df["Transmission"])

# %%
df.head()
# Out:
#                                   Location  Year  Kilometers_Driven  \
# Name
# Maruti Wagon R LXI CNG                   9    12              72000
# Hyundai Creta 1.6 CRDi SX Option        10    17              41000
# Honda Jazz V                             2    13              46000
# Maruti Ertiga VDI                        2    14              87000
# Audi A4 New 2.0 TDI Multitronic          3    15              40670
#
#                                   Fuel_Type  Transmission  Owner_Type  \
# Name
# Maruti Wagon R LXI CNG                    0             1           0
# Hyundai Creta 1.6 CRDi SX Option          1             1           0
# Honda Jazz V                              4             1           0
# Maruti Ertiga VDI                         1             1           0
# Audi A4 New 2.0 TDI Multitronic           1             0           2
#
#                                      Mileage   Engine      Power  Seats  Price
# Name
# ...

# %%
df["Mileage"]=df['Mileage'] = df['Mileage'].str.replace('km/kg', '')
df["Mileage"]=df['Mileage'] = df['Mileage'].str.replace('kmpl', '')
df["Engine"]=df['Engine'] = df['Engine'].str.replace('CC', '')
df["Power"]=df['Power'] = df['Power'].str.replace('bhp', '')
df = df.apply(pd.to_numeric, errors='coerce')
df.dtypes
# Out:
# Location               int64
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type              int64
# Transmission           int32
# Owner_Type             int64
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# dtype: object

# %%
df.fillna(value=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
X=np.array(df.drop("Price",1))
y=df["Price"]
X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.3)

# %%
clf=LinearRegression()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.5048260237275319

# %%
clf=Ridge()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.5047374951988713

# %%
clf=Lasso()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.37981110584782385

# %%
clf=RandomForestRegressor()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# C:\Users\MMOHTASHIM\Anaconda3\envs\env_full\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8714429235651051

# %%
tuned_parameters = {'n_estimators': [500, 700, 1000], 'max_depth': [None,1, 2, 3], 'min_samples_split': [2, 3, 4]}
clf = GridSearchCV(RandomForestRegressor(), tuned_parameters, cv=5, 
                   n_jobs=-1, verbose=1)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:  5.8min finished
# 0.8767519700392598

# %%
clf=GradientBoostingRegressor()
clf.fit(X_train,y_train)
clf.score(X_test,y_test)
# Out:
# 0.8690292470794869

# %%
df_2=pd.DataFrame({"Regressions Algorithms":["LinearRegression","Ridge",'Lasso','RandomForestRegressor',
                                            'GradientBoostingRegressor'],"Scores":[0.5048260237275319,
                                                                                                                  0.5047374951988713,
                                                                                                                  0.37981110584782385,
                                                                                                                  0.8714429235651051,
                                                                                  0.8690292470794869]})

# %%
df_2
# Out:
#       Regressions Algorithms    Scores
# 0           LinearRegression  0.504826
# 1                      Ridge  0.504737
# 2                      Lasso  0.379811
# 3      RandomForestRegressor  0.871443
# 4  GradientBoostingRegressor  0.869029

# %%
##passing the dataset through the same pipline
df_test=pd.read_excel("test.xlsx")
df_test.set_index((df.columns[0]),inplace=True)
df_test.drop("New_Price",1,inplace=True)
LabelEncoder=LabelEncoder()
df_test["Location"]=LabelEncoder.fit_transform(df_test["Location"])
df_test["Year"]=LabelEncoder.fit_transform(df_test["Year"])
df_test["Fuel_Type"]=LabelEncoder.fit_transform(df_test["Fuel_Type"])
df_test["Owner_Type"]=LabelEncoder.fit_transform(df_test["Owner_Type"])
df_test["Transmission"]=LabelEncoder.fit_transform(df_test["Transmission"])
df_test["Mileage"]=df_test['Mileage'].str.replace('km/kg', '')
df_test["Mileage"]=df_test['Mileage'].str.replace('kmpl', '')
df_test["Engine"]=df_test['Engine'].str.replace('CC', '')
df_test["Power"]=df_test['Power'].str.replace('bhp', '')
df_test = df_test.apply(pd.to_numeric, errors='coerce')
df_test.fillna(value=0,inplace=True)

# %%
df_test.head()
# Out:
#                                            Location  Year  Kilometers_Driven  \
# Name
# Maruti Alto K10 LXI CNG                           4    14              40929
# Maruti Alto 800 2016-2019 LXI                     3    13              54493
# Toyota Innova Crysta Touring Sport 2.4 MT         9    17              34000
# Toyota Etios Liva GD                              5    12             139000
# Hyundai i20 Magna                                 9    14              29000
#
#                                            Fuel_Type  Transmission  \
# Name
# Maruti Alto K10 LXI CNG                            0             1
# Maruti Alto 800 2016-2019 LXI                      3             1
# Toyota Innova Crysta Touring Sport 2.4 MT          1             1
# Toyota Etios Liva GD                               1             1
# Hyundai i20 Magna                                  3             1
#
#                                            Owner_Type  Mileage  Engine  \
# Name
# ...

# %%
clf=RandomForestRegressor()
clf.fit(X,y)
X_test=np.array(df_test)
predictions=clf.predict(X_test)
# Out:
# C:\Users\MMOHTASHIM\Anaconda3\envs\env_full\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
df_pred=pd.DataFrame(predictions)
df_pred.to_excel("submission.xlsx")

# %%
predictions
# Out:
# array([ 2.485,  2.966, 16.759, ...,  2.014,  3.502, 15.77 ])
